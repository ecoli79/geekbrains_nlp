# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import sklearn
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
devices = tf.config.list_physical_devices('GPU')
devices
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# --2022-11-27 06:34:49--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15011848 (14M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  14.32M  1.06MB/s    in 10s
#
# 2022-11-27 06:35:00 (1.39 MB/s) - ‘rus-eng.zip’ saved [15011848/15011848]
#
# mkdir: cannot create directory ‘rus-eng’: File exists
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls ./rus-eng/
# Out:
# _about.txt  rus.txt

# %%
path_to_file = './rus-eng/rus.txt'

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence('Just do it!')
# Out:
# '<start> just do it ! <end>'

# %%
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[140])
print(ru[140])
# Out:
# <start> i lied . <end>
# <start> я солгал . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Let's create model and train it

# %%
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, 
                                                                                                target_tensor,
                                                                                                test_size=0.2)

# %%
def convert(lang, tensor):
    for t in tensor:
        if t != 0:
            print(f"{t} ----> {lang.index_word[t]}")

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 16020 ----> гвоздика
# 8 ----> это
# 16021 ----> пряность
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 6143 ----> cloves
# 20 ----> are
# 9 ----> a
# 4719 ----> spice
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# #### create a tf.data and dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train) // BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences = False,
                                       return_state= True,
                                       recurrent_initializer = 'glorot_uniform')
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return state
    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences = True,
                                       return_state = True,
                                       recurrent_initializer = 'glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)
    
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        x = self.fc(output)
        
        return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %% [markdown]
# #### optimizer and loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_text_translate_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %% [markdown]
# #### let's training

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6907
# Epoch 1 Batch 100 Loss 2.1062
# Epoch 1 Batch 200 Loss 1.7444
# Epoch 1 Batch 300 Loss 1.5644
# Epoch 1 Batch 400 Loss 1.5031
# Epoch 1 Batch 500 Loss 1.4079
# Epoch 1 Batch 600 Loss 1.3814
# Epoch 1 Batch 700 Loss 1.1789
# Epoch 1 Batch 800 Loss 1.2298
# Epoch 1 Batch 900 Loss 1.0377
# Epoch 1 Batch 1000 Loss 0.9653
# Epoch 1 Batch 1100 Loss 0.9414
# Epoch 1 Batch 1200 Loss 0.9733
# Epoch 1 Loss 1.4025
# Time taken for 1 epoch 55.67898774147034 sec
#
# Epoch 2 Batch 0 Loss 0.8345
# Epoch 2 Batch 100 Loss 0.8310
# Epoch 2 Batch 200 Loss 0.8239
# Epoch 2 Batch 300 Loss 0.7965
# Epoch 2 Batch 400 Loss 0.7980
# Epoch 2 Batch 500 Loss 0.7795
# Epoch 2 Batch 600 Loss 0.6503
# Epoch 2 Batch 700 Loss 0.7377
# Epoch 2 Batch 800 Loss 0.5588
# Epoch 2 Batch 900 Loss 0.6804
# Epoch 2 Batch 1000 Loss 0.5529
# Epoch 2 Batch 1100 Loss 0.6496
# Epoch 2 Batch 1200 Loss 0.5308
# Epoch 2 Loss 0.6796
# Time taken for 1 epoch 36.8255660533905 sec
#
# Epoch 3 Batch 0 Loss 0.3839
# Epoch 3 Batch 100 Loss 0.4128
# Epoch 3 Batch 200 Loss 0.3590
# Epoch 3 Batch 300 Loss 0.4001
# Epoch 3 Batch 400 Loss 0.3567
# Epoch 3 Batch 500 Loss 0.4167
# Epoch 3 Batch 600 Loss 0.3337
# Epoch 3 Batch 700 Loss 0.3586
# Epoch 3 Batch 800 Loss 0.3861
# Epoch 3 Batch 900 Loss 0.3445
# Epoch 3 Batch 1000 Loss 0.3411
# Epoch 3 Batch 1100 Loss 0.3189
# Epoch 3 Batch 1200 Loss 0.3372
# Epoch 3 Loss 0.3700
# Time taken for 1 epoch 36.214245557785034 sec
#
# Epoch 4 Batch 0 Loss 0.2696
# Epoch 4 Batch 100 Loss 0.2687
# Epoch 4 Batch 200 Loss 0.2083
# Epoch 4 Batch 300 Loss 0.3145
# Epoch 4 Batch 400 Loss 0.2985
# Epoch 4 Batch 500 Loss 0.2261
# Epoch 4 Batch 600 Loss 0.2374
# Epoch 4 Batch 700 Loss 0.2527
# Epoch 4 Batch 800 Loss 0.2490
# Epoch 4 Batch 900 Loss 0.2500
# Epoch 4 Batch 1000 Loss 0.2588
# Epoch 4 Batch 1100 Loss 0.2456
# Epoch 4 Batch 1200 Loss 0.2259
# Epoch 4 Loss 0.2233
# Time taken for 1 epoch 36.21183681488037 sec
#
# Epoch 5 Batch 0 Loss 0.1326
# Epoch 5 Batch 100 Loss 0.1744
# Epoch 5 Batch 200 Loss 0.1377
# Epoch 5 Batch 300 Loss 0.1217
# Epoch 5 Batch 400 Loss 0.1566
# Epoch 5 Batch 500 Loss 0.1199
# Epoch 5 Batch 600 Loss 0.1613
# Epoch 5 Batch 700 Loss 0.1212
# Epoch 5 Batch 800 Loss 0.1559
# Epoch 5 Batch 900 Loss 0.2007
# Epoch 5 Batch 1000 Loss 0.1654
# Epoch 5 Batch 1100 Loss 0.1579
# Epoch 5 Batch 1200 Loss 0.1739
# Epoch 5 Loss 0.1535
# Time taken for 1 epoch 35.72943687438965 sec
#
# Epoch 6 Batch 0 Loss 0.1061
# Epoch 6 Batch 100 Loss 0.0895
# Epoch 6 Batch 200 Loss 0.1133
# Epoch 6 Batch 300 Loss 0.1023
# Epoch 6 Batch 400 Loss 0.1069
# Epoch 6 Batch 500 Loss 0.0831
# Epoch 6 Batch 600 Loss 0.1286
# Epoch 6 Batch 700 Loss 0.1200
# Epoch 6 Batch 800 Loss 0.0925
# Epoch 6 Batch 900 Loss 0.1655
# Epoch 6 Batch 1000 Loss 0.1696
# Epoch 6 Batch 1100 Loss 0.1350
# Epoch 6 Batch 1200 Loss 0.1640
# Epoch 6 Loss 0.1186
# Time taken for 1 epoch 36.04123878479004 sec
#
# Epoch 7 Batch 0 Loss 0.0569
# Epoch 7 Batch 100 Loss 0.0634
# Epoch 7 Batch 200 Loss 0.1060
# Epoch 7 Batch 300 Loss 0.1210
# Epoch 7 Batch 400 Loss 0.1105
# Epoch 7 Batch 500 Loss 0.0803
# Epoch 7 Batch 600 Loss 0.1045
# Epoch 7 Batch 700 Loss 0.1199
# Epoch 7 Batch 800 Loss 0.1273
# Epoch 7 Batch 900 Loss 0.1196
# Epoch 7 Batch 1000 Loss 0.1006
# Epoch 7 Batch 1100 Loss 0.1705
# Epoch 7 Batch 1200 Loss 0.0837
# Epoch 7 Loss 0.1016
# Time taken for 1 epoch 35.759849548339844 sec
#
# Epoch 8 Batch 0 Loss 0.1065
# Epoch 8 Batch 100 Loss 0.1006
# Epoch 8 Batch 200 Loss 0.0799
# Epoch 8 Batch 300 Loss 0.0898
# Epoch 8 Batch 400 Loss 0.0555
# Epoch 8 Batch 500 Loss 0.0717
# Epoch 8 Batch 600 Loss 0.0835
# Epoch 8 Batch 700 Loss 0.0960
# Epoch 8 Batch 800 Loss 0.0810
# Epoch 8 Batch 900 Loss 0.0812
# Epoch 8 Batch 1000 Loss 0.1033
# Epoch 8 Batch 1100 Loss 0.0902
# Epoch 8 Batch 1200 Loss 0.1361
# Epoch 8 Loss 0.0905
# Time taken for 1 epoch 36.7208685874939 sec
#
# Epoch 9 Batch 0 Loss 0.0687
# Epoch 9 Batch 100 Loss 0.0577
# Epoch 9 Batch 200 Loss 0.0715
# Epoch 9 Batch 300 Loss 0.0750
# Epoch 9 Batch 400 Loss 0.0552
# Epoch 9 Batch 500 Loss 0.0658
# Epoch 9 Batch 600 Loss 0.1097
# Epoch 9 Batch 700 Loss 0.0807
# Epoch 9 Batch 800 Loss 0.0857
# Epoch 9 Batch 900 Loss 0.0946
# Epoch 9 Batch 1000 Loss 0.0729
# Epoch 9 Batch 1100 Loss 0.1216
# Epoch 9 Batch 1200 Loss 0.1244
# Epoch 9 Loss 0.0855
# Time taken for 1 epoch 36.08076858520508 sec
#
# Epoch 10 Batch 0 Loss 0.0581
# Epoch 10 Batch 100 Loss 0.0630
# Epoch 10 Batch 200 Loss 0.0629
# Epoch 10 Batch 300 Loss 0.0510
# Epoch 10 Batch 400 Loss 0.0561
# Epoch 10 Batch 500 Loss 0.0781
# Epoch 10 Batch 600 Loss 0.0886
# Epoch 10 Batch 700 Loss 0.0718
# Epoch 10 Batch 800 Loss 0.0934
# Epoch 10 Batch 900 Loss 0.1062
# Epoch 10 Batch 1000 Loss 0.0688
# Epoch 10 Batch 1100 Loss 0.0887
# Epoch 10 Batch 1200 Loss 0.0689
# Epoch 10 Loss 0.0815
# Time taken for 1 epoch 36.14830994606018 sec
#
# Epoch 11 Batch 0 Loss 0.0469
# Epoch 11 Batch 100 Loss 0.0465
# Epoch 11 Batch 200 Loss 0.0528
# Epoch 11 Batch 300 Loss 0.0637
# Epoch 11 Batch 400 Loss 0.0605
# Epoch 11 Batch 500 Loss 0.0613
# Epoch 11 Batch 600 Loss 0.0596
# Epoch 11 Batch 700 Loss 0.1198
# Epoch 11 Batch 800 Loss 0.0676
# Epoch 11 Batch 900 Loss 0.0935
# Epoch 11 Batch 1000 Loss 0.0739
# Epoch 11 Batch 1100 Loss 0.1161
# Epoch 11 Batch 1200 Loss 0.0970
# Epoch 11 Loss 0.0776
# Time taken for 1 epoch 35.77981901168823 sec
#
# Epoch 12 Batch 0 Loss 0.0525
# Epoch 12 Batch 100 Loss 0.0453
# Epoch 12 Batch 200 Loss 0.0915
# Epoch 12 Batch 300 Loss 0.0516
# Epoch 12 Batch 400 Loss 0.0525
# Epoch 12 Batch 500 Loss 0.0853
# Epoch 12 Batch 600 Loss 0.0522
# Epoch 12 Batch 700 Loss 0.0848
# Epoch 12 Batch 800 Loss 0.0639
# Epoch 12 Batch 900 Loss 0.1139
# Epoch 12 Batch 1000 Loss 0.0666
# Epoch 12 Batch 1100 Loss 0.0912
# Epoch 12 Batch 1200 Loss 0.0627
# Epoch 12 Loss 0.0752
# Time taken for 1 epoch 36.159728050231934 sec
#
# Epoch 13 Batch 0 Loss 0.1033
# Epoch 13 Batch 100 Loss 0.0844
# Epoch 13 Batch 200 Loss 0.0752
# Epoch 13 Batch 300 Loss 0.0570
# Epoch 13 Batch 400 Loss 0.0670
# Epoch 13 Batch 500 Loss 0.0872
# Epoch 13 Batch 600 Loss 0.0841
# Epoch 13 Batch 700 Loss 0.1004
# Epoch 13 Batch 800 Loss 0.0743
# Epoch 13 Batch 900 Loss 0.0511
# Epoch 13 Batch 1000 Loss 0.0807
# Epoch 13 Batch 1100 Loss 0.0651
# Epoch 13 Batch 1200 Loss 0.0811
# Epoch 13 Loss 0.0730
# Time taken for 1 epoch 35.94815397262573 sec
#
# Epoch 14 Batch 0 Loss 0.0401
# Epoch 14 Batch 100 Loss 0.0416
# Epoch 14 Batch 200 Loss 0.0569
# Epoch 14 Batch 300 Loss 0.0508
# Epoch 14 Batch 400 Loss 0.0558
# Epoch 14 Batch 500 Loss 0.0435
# Epoch 14 Batch 600 Loss 0.1064
# Epoch 14 Batch 700 Loss 0.0743
# Epoch 14 Batch 800 Loss 0.0816
# Epoch 14 Batch 900 Loss 0.0691
# Epoch 14 Batch 1000 Loss 0.0794
# Epoch 14 Batch 1100 Loss 0.1102
# Epoch 14 Batch 1200 Loss 0.1012
# Epoch 14 Loss 0.0712
# Time taken for 1 epoch 36.170522689819336 sec
#
# Epoch 15 Batch 0 Loss 0.0336
# Epoch 15 Batch 100 Loss 0.0484
# Epoch 15 Batch 200 Loss 0.0551
# Epoch 15 Batch 300 Loss 0.0526
# Epoch 15 Batch 400 Loss 0.0805
# Epoch 15 Batch 500 Loss 0.0407
# Epoch 15 Batch 600 Loss 0.0483
# Epoch 15 Batch 700 Loss 0.0578
# Epoch 15 Batch 800 Loss 0.0550
# Epoch 15 Batch 900 Loss 0.0636
# Epoch 15 Batch 1000 Loss 0.0912
# Epoch 15 Batch 1100 Loss 0.1142
# Epoch 15 Batch 1200 Loss 0.0469
# Epoch 15 Loss 0.0700
# Time taken for 1 epoch 35.85120916366577 sec
#
# Epoch 16 Batch 0 Loss 0.0585
# Epoch 16 Batch 100 Loss 0.0473
# Epoch 16 Batch 200 Loss 0.0534
# Epoch 16 Batch 300 Loss 0.0425
# Epoch 16 Batch 400 Loss 0.0608
# Epoch 16 Batch 500 Loss 0.0412
# Epoch 16 Batch 600 Loss 0.0738
# Epoch 16 Batch 700 Loss 0.0558
# Epoch 16 Batch 800 Loss 0.0811
# Epoch 16 Batch 900 Loss 0.1079
# Epoch 16 Batch 1000 Loss 0.0363
# Epoch 16 Batch 1100 Loss 0.0622
# Epoch 16 Batch 1200 Loss 0.0674
# Epoch 16 Loss 0.0674
# Time taken for 1 epoch 36.13935661315918 sec
#
# Epoch 17 Batch 0 Loss 0.0628
# Epoch 17 Batch 100 Loss 0.0237
# Epoch 17 Batch 200 Loss 0.0551
# Epoch 17 Batch 300 Loss 0.0640
# Epoch 17 Batch 400 Loss 0.0723
# Epoch 17 Batch 500 Loss 0.0797
# Epoch 17 Batch 600 Loss 0.1248
# Epoch 17 Batch 700 Loss 0.0672
# Epoch 17 Batch 800 Loss 0.0744
# Epoch 17 Batch 900 Loss 0.0537
# Epoch 17 Batch 1000 Loss 0.0960
# Epoch 17 Batch 1100 Loss 0.0822
# Epoch 17 Batch 1200 Loss 0.0854
# Epoch 17 Loss 0.0668
# Time taken for 1 epoch 35.8379271030426 sec
#
# Epoch 18 Batch 0 Loss 0.0327
# Epoch 18 Batch 100 Loss 0.0559
# Epoch 18 Batch 200 Loss 0.0365
# Epoch 18 Batch 300 Loss 0.0543
# Epoch 18 Batch 400 Loss 0.0587
# Epoch 18 Batch 500 Loss 0.0419
# Epoch 18 Batch 600 Loss 0.0725
# Epoch 18 Batch 700 Loss 0.0788
# Epoch 18 Batch 800 Loss 0.0904
# Epoch 18 Batch 900 Loss 0.1114
# Epoch 18 Batch 1000 Loss 0.0772
# Epoch 18 Batch 1100 Loss 0.0930
# Epoch 18 Batch 1200 Loss 0.0770
# Epoch 18 Loss 0.0653
# Time taken for 1 epoch 36.215676069259644 sec
#
# Epoch 19 Batch 0 Loss 0.0518
# Epoch 19 Batch 100 Loss 0.0307
# Epoch 19 Batch 200 Loss 0.0737
# Epoch 19 Batch 300 Loss 0.0445
# Epoch 19 Batch 400 Loss 0.0531
# Epoch 19 Batch 500 Loss 0.0860
# Epoch 19 Batch 600 Loss 0.0791
# Epoch 19 Batch 700 Loss 0.0353
# Epoch 19 Batch 800 Loss 0.0639
# Epoch 19 Batch 900 Loss 0.0695
# Epoch 19 Batch 1000 Loss 0.0462
# Epoch 19 Batch 1100 Loss 0.0876
# Epoch 19 Batch 1200 Loss 0.0800
# Epoch 19 Loss 0.0643
# Time taken for 1 epoch 35.95284867286682 sec
#
# Epoch 20 Batch 0 Loss 0.0352
# Epoch 20 Batch 100 Loss 0.0311
# Epoch 20 Batch 200 Loss 0.0825
# Epoch 20 Batch 300 Loss 0.0387
# Epoch 20 Batch 400 Loss 0.0615
# Epoch 20 Batch 500 Loss 0.0393
# Epoch 20 Batch 600 Loss 0.0555
# Epoch 20 Batch 700 Loss 0.0683
# Epoch 20 Batch 800 Loss 0.0623
# Epoch 20 Batch 900 Loss 0.0501
# Epoch 20 Batch 1000 Loss 0.0749
# Epoch 20 Batch 1100 Loss 0.0556
# Epoch 20 Batch 1200 Loss 0.1069
# Epoch 20 Loss 0.0628
# Time taken for 1 epoch 36.289615631103516 sec
#
# Epoch 21 Batch 0 Loss 0.0825
# Epoch 21 Batch 100 Loss 0.0691
# Epoch 21 Batch 200 Loss 0.0603
# Epoch 21 Batch 300 Loss 0.0335
# Epoch 21 Batch 400 Loss 0.0527
# Epoch 21 Batch 500 Loss 0.0487
# Epoch 21 Batch 600 Loss 0.0655
# Epoch 21 Batch 700 Loss 0.0879
# Epoch 21 Batch 800 Loss 0.0639
# Epoch 21 Batch 900 Loss 0.0843
# Epoch 21 Batch 1000 Loss 0.0967
# Epoch 21 Batch 1100 Loss 0.0859
# Epoch 21 Batch 1200 Loss 0.0492
# Epoch 21 Loss 0.0627
# Time taken for 1 epoch 35.834376096725464 sec
#
# Epoch 22 Batch 0 Loss 0.0726
# Epoch 22 Batch 100 Loss 0.0831
# Epoch 22 Batch 200 Loss 0.0575
# Epoch 22 Batch 300 Loss 0.0542
# Epoch 22 Batch 400 Loss 0.0256
# Epoch 22 Batch 500 Loss 0.0954
# Epoch 22 Batch 600 Loss 0.0926
# Epoch 22 Batch 700 Loss 0.0649
# Epoch 22 Batch 800 Loss 0.0441
# Epoch 22 Batch 900 Loss 0.0626
# Epoch 22 Batch 1000 Loss 0.0440
# Epoch 22 Batch 1100 Loss 0.0532
# Epoch 22 Batch 1200 Loss 0.0778
# Epoch 22 Loss 0.0616
# Time taken for 1 epoch 36.271023750305176 sec
#
# Epoch 23 Batch 0 Loss 0.0463
# Epoch 23 Batch 100 Loss 0.0608
# Epoch 23 Batch 200 Loss 0.0361
# Epoch 23 Batch 300 Loss 0.0704
# Epoch 23 Batch 400 Loss 0.0590
# Epoch 23 Batch 500 Loss 0.0578
# Epoch 23 Batch 600 Loss 0.0784
# Epoch 23 Batch 700 Loss 0.0564
# Epoch 23 Batch 800 Loss 0.0678
# Epoch 23 Batch 900 Loss 0.0622
# Epoch 23 Batch 1000 Loss 0.0665
# Epoch 23 Batch 1100 Loss 0.0524
# Epoch 23 Batch 1200 Loss 0.0686
# Epoch 23 Loss 0.0613
# Time taken for 1 epoch 35.84207010269165 sec
#
# Epoch 24 Batch 0 Loss 0.0605
# Epoch 24 Batch 100 Loss 0.0657
# Epoch 24 Batch 200 Loss 0.0690
# Epoch 24 Batch 300 Loss 0.0524
# Epoch 24 Batch 400 Loss 0.0744
# Epoch 24 Batch 500 Loss 0.0502
# Epoch 24 Batch 600 Loss 0.1014
# Epoch 24 Batch 700 Loss 0.0879
# Epoch 24 Batch 800 Loss 0.1217
# Epoch 24 Batch 900 Loss 0.1204
# Epoch 24 Batch 1000 Loss 0.0802
# Epoch 24 Batch 1100 Loss 0.0569
# Epoch 24 Batch 1200 Loss 0.0702
# Epoch 24 Loss 0.0606
# Time taken for 1 epoch 36.25255370140076 sec
#
# Epoch 25 Batch 0 Loss 0.0364
# Epoch 25 Batch 100 Loss 0.0410
# Epoch 25 Batch 200 Loss 0.0260
# Epoch 25 Batch 300 Loss 0.1169
# Epoch 25 Batch 400 Loss 0.0334
# Epoch 25 Batch 500 Loss 0.0771
# Epoch 25 Batch 600 Loss 0.0467
# Epoch 25 Batch 700 Loss 0.0448
# Epoch 25 Batch 800 Loss 0.0484
# Epoch 25 Batch 900 Loss 0.0801
# Epoch 25 Batch 1000 Loss 0.0812
# Epoch 25 Batch 1100 Loss 0.0623
# Epoch 25 Batch 1200 Loss 0.1061
# Epoch 25 Loss 0.0594
# Time taken for 1 epoch 35.83687901496887 sec
#
# Epoch 26 Batch 0 Loss 0.0515
# Epoch 26 Batch 100 Loss 0.0746
# Epoch 26 Batch 200 Loss 0.0671
# Epoch 26 Batch 300 Loss 0.0442
# Epoch 26 Batch 400 Loss 0.0917
# Epoch 26 Batch 500 Loss 0.0354
# Epoch 26 Batch 600 Loss 0.0251
# Epoch 26 Batch 700 Loss 0.0572
# Epoch 26 Batch 800 Loss 0.0446
# Epoch 26 Batch 900 Loss 0.0233
# Epoch 26 Batch 1000 Loss 0.0494
# Epoch 26 Batch 1100 Loss 0.0922
# Epoch 26 Batch 1200 Loss 0.0723
# Epoch 26 Loss 0.0580
# Time taken for 1 epoch 36.24488401412964 sec
#
# Epoch 27 Batch 0 Loss 0.0442
# Epoch 27 Batch 100 Loss 0.0534
# Epoch 27 Batch 200 Loss 0.0446
# Epoch 27 Batch 300 Loss 0.0671
# Epoch 27 Batch 400 Loss 0.0582
# Epoch 27 Batch 500 Loss 0.0485
# Epoch 27 Batch 600 Loss 0.0706
# Epoch 27 Batch 700 Loss 0.0918
# Epoch 27 Batch 800 Loss 0.0775
# Epoch 27 Batch 900 Loss 0.0845
# Epoch 27 Batch 1000 Loss 0.0713
# Epoch 27 Batch 1100 Loss 0.0452
# Epoch 27 Batch 1200 Loss 0.0876
# Epoch 27 Loss 0.0578
# Time taken for 1 epoch 35.83848285675049 sec
#
# Epoch 28 Batch 0 Loss 0.0341
# Epoch 28 Batch 100 Loss 0.0759
# Epoch 28 Batch 200 Loss 0.0605
# Epoch 28 Batch 300 Loss 0.1078
# Epoch 28 Batch 400 Loss 0.0612
# Epoch 28 Batch 500 Loss 0.0868
# Epoch 28 Batch 600 Loss 0.0281
# Epoch 28 Batch 700 Loss 0.0314
# Epoch 28 Batch 800 Loss 0.0428
# Epoch 28 Batch 900 Loss 0.0742
# Epoch 28 Batch 1000 Loss 0.0654
# Epoch 28 Batch 1100 Loss 0.0592
# Epoch 28 Batch 1200 Loss 0.0907
# Epoch 28 Loss 0.0570
# Time taken for 1 epoch 36.255754470825195 sec
#
# Epoch 29 Batch 0 Loss 0.0428
# Epoch 29 Batch 100 Loss 0.0505
# Epoch 29 Batch 200 Loss 0.0253
# Epoch 29 Batch 300 Loss 0.0442
# Epoch 29 Batch 400 Loss 0.0462
# Epoch 29 Batch 500 Loss 0.0445
# Epoch 29 Batch 600 Loss 0.0295
# Epoch 29 Batch 700 Loss 0.0399
# Epoch 29 Batch 800 Loss 0.0595
# Epoch 29 Batch 900 Loss 0.0866
# Epoch 29 Batch 1000 Loss 0.0501
# Epoch 29 Batch 1100 Loss 0.1324
# Epoch 29 Batch 1200 Loss 0.0614
# Epoch 29 Loss 0.0567
# Time taken for 1 epoch 35.850648403167725 sec
#
# Epoch 30 Batch 0 Loss 0.0399
# Epoch 30 Batch 100 Loss 0.0350
# Epoch 30 Batch 200 Loss 0.0254
# Epoch 30 Batch 300 Loss 0.0446
# Epoch 30 Batch 400 Loss 0.0424
# Epoch 30 Batch 500 Loss 0.0504
# Epoch 30 Batch 600 Loss 0.0501
# Epoch 30 Batch 700 Loss 0.0978
# Epoch 30 Batch 800 Loss 0.0289
# Epoch 30 Batch 900 Loss 0.0482
# Epoch 30 Batch 1000 Loss 0.0752
# Epoch 30 Batch 1100 Loss 0.0362
# Epoch 30 Batch 1200 Loss 0.0566
# Epoch 30 Loss 0.0555
# Time taken for 1 epoch 36.25922727584839 sec
#
# Epoch 31 Batch 0 Loss 0.0928
# Epoch 31 Batch 100 Loss 0.0334
# Epoch 31 Batch 200 Loss 0.0428
# Epoch 31 Batch 300 Loss 0.0132
# Epoch 31 Batch 400 Loss 0.0725
# Epoch 31 Batch 500 Loss 0.0733
# Epoch 31 Batch 600 Loss 0.0565
# Epoch 31 Batch 700 Loss 0.0736
# Epoch 31 Batch 800 Loss 0.0478
# Epoch 31 Batch 900 Loss 0.1170
# Epoch 31 Batch 1000 Loss 0.0955
# Epoch 31 Batch 1100 Loss 0.0772
# Epoch 31 Batch 1200 Loss 0.1227
# Epoch 31 Loss 0.0551
# Time taken for 1 epoch 35.81140446662903 sec
#
# Epoch 32 Batch 0 Loss 0.0317
# Epoch 32 Batch 100 Loss 0.0314
# Epoch 32 Batch 200 Loss 0.0174
# Epoch 32 Batch 300 Loss 0.0310
# Epoch 32 Batch 400 Loss 0.0399
# Epoch 32 Batch 500 Loss 0.0716
# Epoch 32 Batch 600 Loss 0.0628
# Epoch 32 Batch 700 Loss 0.0613
# Epoch 32 Batch 800 Loss 0.0650
# Epoch 32 Batch 900 Loss 0.0453
# Epoch 32 Batch 1000 Loss 0.1210
# Epoch 32 Batch 1100 Loss 0.0815
# Epoch 32 Batch 1200 Loss 0.0396
# Epoch 32 Loss 0.0543
# Time taken for 1 epoch 36.27052116394043 sec
#
# Epoch 33 Batch 0 Loss 0.0170
# Epoch 33 Batch 100 Loss 0.0652
# Epoch 33 Batch 200 Loss 0.0412
# Epoch 33 Batch 300 Loss 0.0597
# Epoch 33 Batch 400 Loss 0.0483
# Epoch 33 Batch 500 Loss 0.0333
# Epoch 33 Batch 600 Loss 0.0602
# Epoch 33 Batch 700 Loss 0.0505
# Epoch 33 Batch 800 Loss 0.0815
# Epoch 33 Batch 900 Loss 0.0751
# Epoch 33 Batch 1000 Loss 0.0630
# Epoch 33 Batch 1100 Loss 0.0449
# Epoch 33 Batch 1200 Loss 0.0478
# Epoch 33 Loss 0.0540
# Time taken for 1 epoch 35.81555414199829 sec
#
# Epoch 34 Batch 0 Loss 0.0940
# Epoch 34 Batch 100 Loss 0.0549
# Epoch 34 Batch 200 Loss 0.0534
# Epoch 34 Batch 300 Loss 0.0569
# Epoch 34 Batch 400 Loss 0.0242
# Epoch 34 Batch 500 Loss 0.0571
# Epoch 34 Batch 600 Loss 0.0514
# Epoch 34 Batch 700 Loss 0.0492
# Epoch 34 Batch 800 Loss 0.0324
# Epoch 34 Batch 900 Loss 0.0547
# Epoch 34 Batch 1000 Loss 0.0438
# Epoch 34 Batch 1100 Loss 0.0212
# Epoch 34 Batch 1200 Loss 0.0548
# Epoch 34 Loss 0.0538
# Time taken for 1 epoch 36.23713541030884 sec
#
# Epoch 35 Batch 0 Loss 0.0624
# Epoch 35 Batch 100 Loss 0.0237
# Epoch 35 Batch 200 Loss 0.0399
# Epoch 35 Batch 300 Loss 0.0394
# Epoch 35 Batch 400 Loss 0.0311
# Epoch 35 Batch 500 Loss 0.0358
# Epoch 35 Batch 600 Loss 0.0740
# Epoch 35 Batch 700 Loss 0.0460
# Epoch 35 Batch 800 Loss 0.0730
# Epoch 35 Batch 900 Loss 0.0494
# Epoch 35 Batch 1000 Loss 0.0514
# Epoch 35 Batch 1100 Loss 0.0862
# Epoch 35 Batch 1200 Loss 0.1026
# Epoch 35 Loss 0.0530
# Time taken for 1 epoch 35.788487672805786 sec
#
# Epoch 36 Batch 0 Loss 0.0484
# Epoch 36 Batch 100 Loss 0.0459
# Epoch 36 Batch 200 Loss 0.0510
# Epoch 36 Batch 300 Loss 0.0499
# Epoch 36 Batch 400 Loss 0.0398
# Epoch 36 Batch 500 Loss 0.0568
# Epoch 36 Batch 600 Loss 0.0478
# Epoch 36 Batch 700 Loss 0.0653
# Epoch 36 Batch 800 Loss 0.0575
# Epoch 36 Batch 900 Loss 0.0632
# Epoch 36 Batch 1000 Loss 0.0574
# Epoch 36 Batch 1100 Loss 0.1110
# Epoch 36 Batch 1200 Loss 0.0912
# Epoch 36 Loss 0.0521
# Time taken for 1 epoch 36.28770470619202 sec
#
# Epoch 37 Batch 0 Loss 0.0271
# Epoch 37 Batch 100 Loss 0.0534
# Epoch 37 Batch 200 Loss 0.0325
# Epoch 37 Batch 300 Loss 0.0604
# Epoch 37 Batch 400 Loss 0.0698
# Epoch 37 Batch 500 Loss 0.0507
# Epoch 37 Batch 600 Loss 0.0631
# Epoch 37 Batch 700 Loss 0.0305
# Epoch 37 Batch 800 Loss 0.0525
# Epoch 37 Batch 900 Loss 0.0657
# Epoch 37 Batch 1000 Loss 0.0754
# Epoch 37 Batch 1100 Loss 0.0398
# Epoch 37 Batch 1200 Loss 0.0446
# Epoch 37 Loss 0.0518
# Time taken for 1 epoch 35.80360388755798 sec
#
# Epoch 38 Batch 0 Loss 0.0309
# Epoch 38 Batch 100 Loss 0.0371
# Epoch 38 Batch 200 Loss 0.0565
# Epoch 38 Batch 300 Loss 0.0366
# Epoch 38 Batch 400 Loss 0.0529
# Epoch 38 Batch 500 Loss 0.0358
# Epoch 38 Batch 600 Loss 0.0776
# Epoch 38 Batch 700 Loss 0.0918
# Epoch 38 Batch 800 Loss 0.0769
# Epoch 38 Batch 900 Loss 0.0651
# Epoch 38 Batch 1000 Loss 0.0445
# Epoch 38 Batch 1100 Loss 0.0917
# Epoch 38 Batch 1200 Loss 0.0523
# Epoch 38 Loss 0.0519
# Time taken for 1 epoch 36.27361035346985 sec
#
# Epoch 39 Batch 0 Loss 0.0296
# Epoch 39 Batch 100 Loss 0.0588
# Epoch 39 Batch 200 Loss 0.0486
# Epoch 39 Batch 300 Loss 0.0380
# Epoch 39 Batch 400 Loss 0.0317
# Epoch 39 Batch 500 Loss 0.0819
# Epoch 39 Batch 600 Loss 0.0553
# Epoch 39 Batch 700 Loss 0.0692
# Epoch 39 Batch 800 Loss 0.0548
# Epoch 39 Batch 900 Loss 0.0447
# Epoch 39 Batch 1000 Loss 0.0584
# Epoch 39 Batch 1100 Loss 0.0360
# Epoch 39 Batch 1200 Loss 0.0545
# Epoch 39 Loss 0.0510
# Time taken for 1 epoch 35.99311017990112 sec
#
# Epoch 40 Batch 0 Loss 0.0749
# Epoch 40 Batch 100 Loss 0.0530
# Epoch 40 Batch 200 Loss 0.0421
# Epoch 40 Batch 300 Loss 0.0406
# Epoch 40 Batch 400 Loss 0.0524
# Epoch 40 Batch 500 Loss 0.0400
# Epoch 40 Batch 600 Loss 0.0717
# Epoch 40 Batch 700 Loss 0.0424
# Epoch 40 Batch 800 Loss 0.0361
# Epoch 40 Batch 900 Loss 0.0272
# Epoch 40 Batch 1000 Loss 0.0515
# Epoch 40 Batch 1100 Loss 0.0869
# Epoch 40 Batch 1200 Loss 0.0444
# Epoch 40 Loss 0.0505
# Time taken for 1 epoch 36.23529624938965 sec
#
# Epoch 41 Batch 0 Loss 0.0541
# Epoch 41 Batch 100 Loss 0.0337
# Epoch 41 Batch 200 Loss 0.0547
# Epoch 41 Batch 300 Loss 0.0449
# Epoch 41 Batch 400 Loss 0.0822
# Epoch 41 Batch 500 Loss 0.0333
# Epoch 41 Batch 600 Loss 0.0742
# Epoch 41 Batch 700 Loss 0.0400
# Epoch 41 Batch 800 Loss 0.0410
# Epoch 41 Batch 900 Loss 0.0417
# Epoch 41 Batch 1000 Loss 0.0593
# Epoch 41 Batch 1100 Loss 0.0641
# Epoch 41 Batch 1200 Loss 0.0471
# Epoch 41 Loss 0.0505
# Time taken for 1 epoch 35.94332838058472 sec
#
# Epoch 42 Batch 0 Loss 0.0384
# Epoch 42 Batch 100 Loss 0.0651
# Epoch 42 Batch 200 Loss 0.0659
# Epoch 42 Batch 300 Loss 0.0383
# Epoch 42 Batch 400 Loss 0.0629
# Epoch 42 Batch 500 Loss 0.0575
# Epoch 42 Batch 600 Loss 0.0362
# Epoch 42 Batch 700 Loss 0.0634
# Epoch 42 Batch 800 Loss 0.0396
# Epoch 42 Batch 900 Loss 0.0575
# Epoch 42 Batch 1000 Loss 0.0750
# Epoch 42 Batch 1100 Loss 0.0735
# Epoch 42 Batch 1200 Loss 0.0481
# Epoch 42 Loss 0.0496
# Time taken for 1 epoch 36.244125843048096 sec
#
# Epoch 43 Batch 0 Loss 0.0209
# Epoch 43 Batch 100 Loss 0.0293
# Epoch 43 Batch 200 Loss 0.0455
# Epoch 43 Batch 300 Loss 0.0456
# Epoch 43 Batch 400 Loss 0.0635
# Epoch 43 Batch 500 Loss 0.0354
# Epoch 43 Batch 600 Loss 0.0692
# Epoch 43 Batch 700 Loss 0.0637
# Epoch 43 Batch 800 Loss 0.0339
# Epoch 43 Batch 900 Loss 0.0845
# Epoch 43 Batch 1000 Loss 0.0462
# Epoch 43 Batch 1100 Loss 0.0655
# Epoch 43 Batch 1200 Loss 0.0533
# Epoch 43 Loss 0.0493
# Time taken for 1 epoch 35.83440089225769 sec
#
# Epoch 44 Batch 0 Loss 0.0560
# Epoch 44 Batch 100 Loss 0.0529
# Epoch 44 Batch 200 Loss 0.0466
# Epoch 44 Batch 300 Loss 0.0196
# Epoch 44 Batch 400 Loss 0.0581
# Epoch 44 Batch 500 Loss 0.0274
# Epoch 44 Batch 600 Loss 0.0399
# Epoch 44 Batch 700 Loss 0.0573
# Epoch 44 Batch 800 Loss 0.0631
# Epoch 44 Batch 900 Loss 0.0514
# Epoch 44 Batch 1000 Loss 0.0836
# Epoch 44 Batch 1100 Loss 0.0532
# Epoch 44 Batch 1200 Loss 0.0582
# Epoch 44 Loss 0.0498
# Time taken for 1 epoch 36.22582411766052 sec
#
# Epoch 45 Batch 0 Loss 0.0466
# Epoch 45 Batch 100 Loss 0.0735
# Epoch 45 Batch 200 Loss 0.0302
# Epoch 45 Batch 300 Loss 0.0373
# Epoch 45 Batch 400 Loss 0.0570
# Epoch 45 Batch 500 Loss 0.0490
# Epoch 45 Batch 600 Loss 0.0415
# Epoch 45 Batch 700 Loss 0.0254
# Epoch 45 Batch 800 Loss 0.0460
# Epoch 45 Batch 900 Loss 0.0744
# Epoch 45 Batch 1000 Loss 0.0479
# Epoch 45 Batch 1100 Loss 0.0451
# Epoch 45 Batch 1200 Loss 0.0595
# Epoch 45 Loss 0.0489
# Time taken for 1 epoch 35.83420419692993 sec
#
# Epoch 46 Batch 0 Loss 0.0380
# Epoch 46 Batch 100 Loss 0.0421
# Epoch 46 Batch 200 Loss 0.0353
# Epoch 46 Batch 300 Loss 0.0886
# Epoch 46 Batch 400 Loss 0.0766
# Epoch 46 Batch 500 Loss 0.0223
# Epoch 46 Batch 600 Loss 0.0511
# Epoch 46 Batch 700 Loss 0.0634
# Epoch 46 Batch 800 Loss 0.0451
# Epoch 46 Batch 900 Loss 0.0618
# Epoch 46 Batch 1000 Loss 0.0857
# Epoch 46 Batch 1100 Loss 0.0766
# Epoch 46 Batch 1200 Loss 0.0322
# Epoch 46 Loss 0.0488
# Time taken for 1 epoch 36.266554832458496 sec
#
# Epoch 47 Batch 0 Loss 0.0343
# Epoch 47 Batch 100 Loss 0.0223
# Epoch 47 Batch 200 Loss 0.0352
# Epoch 47 Batch 300 Loss 0.0435
# Epoch 47 Batch 400 Loss 0.0269
# Epoch 47 Batch 500 Loss 0.0560
# Epoch 47 Batch 600 Loss 0.0635
# Epoch 47 Batch 700 Loss 0.0380
# Epoch 47 Batch 800 Loss 0.0368
# Epoch 47 Batch 900 Loss 0.0451
# Epoch 47 Batch 1000 Loss 0.0521
# Epoch 47 Batch 1100 Loss 0.0538
# Epoch 47 Batch 1200 Loss 0.0705
# Epoch 47 Loss 0.0485
# Time taken for 1 epoch 35.85760426521301 sec
#
# Epoch 48 Batch 0 Loss 0.0393
# Epoch 48 Batch 100 Loss 0.0349
# Epoch 48 Batch 200 Loss 0.0228
# Epoch 48 Batch 300 Loss 0.0370
# Epoch 48 Batch 400 Loss 0.0515
# Epoch 48 Batch 500 Loss 0.0328
# Epoch 48 Batch 600 Loss 0.0273
# Epoch 48 Batch 700 Loss 0.0527
# Epoch 48 Batch 800 Loss 0.0628
# Epoch 48 Batch 900 Loss 0.0479
# Epoch 48 Batch 1000 Loss 0.0442
# Epoch 48 Batch 1100 Loss 0.0306
# Epoch 48 Batch 1200 Loss 0.0531
# Epoch 48 Loss 0.0478
# Time taken for 1 epoch 36.19550085067749 sec
#
# Epoch 49 Batch 0 Loss 0.0482
# Epoch 49 Batch 100 Loss 0.0371
# Epoch 49 Batch 200 Loss 0.0197
# Epoch 49 Batch 300 Loss 0.0739
# Epoch 49 Batch 400 Loss 0.0298
# Epoch 49 Batch 500 Loss 0.0507
# Epoch 49 Batch 600 Loss 0.0304
# Epoch 49 Batch 700 Loss 0.0794
# Epoch 49 Batch 800 Loss 0.0452
# Epoch 49 Batch 900 Loss 0.0666
# Epoch 49 Batch 1000 Loss 0.0404
# Epoch 49 Batch 1100 Loss 0.0736
# Epoch 49 Batch 1200 Loss 0.0638
# Epoch 49 Loss 0.0475
# Time taken for 1 epoch 35.85333561897278 sec
#
# Epoch 50 Batch 0 Loss 0.0361
# Epoch 50 Batch 100 Loss 0.0308
# Epoch 50 Batch 200 Loss 0.0166
# Epoch 50 Batch 300 Loss 0.0200
# Epoch 50 Batch 400 Loss 0.0507
# Epoch 50 Batch 500 Loss 0.0276
# Epoch 50 Batch 600 Loss 0.0338
# Epoch 50 Batch 700 Loss 0.0340
# Epoch 50 Batch 800 Loss 0.0648
# Epoch 50 Batch 900 Loss 0.0344
# Epoch 50 Batch 1000 Loss 0.0730
# Epoch 50 Batch 1100 Loss 0.0577
# Epoch 50 Batch 1200 Loss 0.0402
# Epoch 50 Loss 0.0475
# Time taken for 1 epoch 36.20957159996033 sec

# %%
def evaluate(sentence):
  #attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print(f'Input: {sentence}')
  print(f'Predicted translation: {result}')

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Все было хорошо')
# Out:
# Input: <start> все было хорошо <end>
# Predicted translation: everyone was good . <end>

# %%
translate('Что вы делали вчера?')
# Out:
# Input: <start> что вы делали вчера ? <end>
# Predicted translation: what did you do then ? <end>
